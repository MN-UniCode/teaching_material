# %% [markdown]
# # Lab 0 - Pytorch Recap
#
# In this laboratory, you will review the main objects that you will need in this course related to PyTorch, the deep learning framework used to develop and train neural networks in Python.
#
# This notebook is heavily based on the tutorials of the [secml-torch library](https://github.com/pralab/secml-torch), [you can find the original here](https://github.com/pralab/secml-torch/blob/main/docs/tutorials/01-introduction.ipynb).

# %% [markdown]
# ## Setup
# We need to setup the environment for this (and the following laboratories).
#
# We will use **virtual environments**, which define a re-usable environment for the laboratories, by specifying the exact software dependancies and their versions.
#
# First, install the [Python](https://marketplace.visualstudio.com/items?itemName=ms-python.python) and [Jupyter Notebook](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) extensions for your Visual Studio code application.
#
#
# Then, clone this repository in your current folder:
#
# ```bash
# git clone git@github.com:zangobot/teaching_material.git
# cd teaching_material
# ```
#
# Once inside the folder, create and activate a virtual environment:
# ```bash
# python -m venv tai_env
# source tai_env/bin/activate
# ```
#
# Now you can activate the environment in Visual Studio code (by clicking on the **Select Kernel** button).
# This will restart the runtime. Once you did this, you can continue below.

# %%
try:
    import secmlt
    import sklearn
    import matplotlib
except ImportError:
    print("Installing the dependancies")
    # %pip install git+https://github.com/pralab/secml-torch
    # %pip install scikit-learn
    # %pip install matplotlib

# %%
import torch
print("Pytorch version:", torch.__version__)

import secmlt
print("secml-torch version:", secmlt.__version__)
# Out:
# Pytorch version: 2.8.0+cu126
# secml-torch version: 1.3

# %% [markdown]
# You should have Pytorch > 2 and secml-torch >= 1.3 installed inside your environment.

# %% [markdown]
# ## Data creation
#
# We now recap the main Pytorch functionalities, by creating some synthetic data, a model, training it and testing it.
# [You can find a complete set of tutorials here.](https://docs.pytorch.org/tutorials/)
#
# Pytorch was created by META but now it become OpenSource.
#
# We first create some data using another library called `scikit-learn`.
#
# Most of the course is gonna deal with 2D data, because we can visualize them.
# If we look at this we can already guess how a machine learning model can divide them.

# %%
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

def plot_data(X, y, title="Data Distribution"):
    """
    Plot the data points colored by their classes.

    Args:
        X: Input features as tensor or numpy array
        y: Labels as tensor or numpy array
        title: Plot title
    """
    # Convert tensors to numpy if needed
    if torch.is_tensor(X):
        X = X.detach().numpy()
    if torch.is_tensor(y):
        y = y.detach().numpy()

    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.title(title)
    plt.show()

# make_blobs: is not offered by Pytorch, these create the 3 clusters
# The random state is always the number for the reproducibility of the results
X, y = make_blobs(n_samples=500,
                  centers=[(0, 1), (0, 0), (1, 1)],
                  n_features=2,
                  cluster_std=0.2, # standard deviation
                  random_state=999)

# Visualize the data
plot_data(X, y, title="Training Data Distribution")

# Convert to PyTorch tensors
X = torch.FloatTensor(X) # store all these tensors in PyTorch way
y = torch.LongTensor(y)

print(f"Data shape: {X.shape}")
print(f"Labels shape: {y.shape}")
# Out:
# Data shape: torch.Size([500, 2])
# Labels shape: torch.Size([500])

# %% [markdown]
# We do the same to create test data, that will be used to compute the accuracy of our model.

# %%
X_test, y_test = make_blobs(n_samples=100,
                  centers=[(0, 1), (0, 0), (1, 1)],
                  n_features=2,
                  cluster_std=0.2,
                  random_state=999)
plot_data(X_test, y_test, title="Test Data Distribution")

# Convert to PyTorch tensors
X_test = torch.FloatTensor(X_test)
y_test = torch.LongTensor(y_test)

print(f"Data shape: {X_test.shape}")
print(f"Labels shape: {y_test.shape}")
# Out:
# Data shape: torch.Size([100, 2])
# Labels shape: torch.Size([100])

# %% [markdown]
# We also already converted those samples in torch Tensors, which are the basic and main Pytorch objects.
#
# Observations are defined as FloatTensors, while labels are LongTensors.
# Input data are continuous data so Float, labels instead are integer and discrete so Long.
#
# We can now create a main concept in Pytorch, which is the DataLoader.
# A DataLoader dispatches data in batches, ready to be used to train models.
#
# In 3D we have a matrix, when we have more complex things, like images, thanks to the DataLoader we can abstract a bit from the data that we have and we can istanciate objects, we use it for efficienty purposes.
# You cannot store anything in just a datacenter due to RAM.
# In general it's a good practice to fit our data in a DataLoader that creates batches and is more efficient.
# So everything, all data, that we will use in this course, are gonna pass through a data loader.

# %%
from torch.utils.data import DataLoader, TensorDataset

dataset = TensorDataset(X, y)
tr_dataloader = DataLoader(dataset, batch_size=32, shuffle=False)
print(f"Number of batches: {len(tr_dataloader)}")
# Out:
# Number of batches: 16

# %% [markdown]
# ### Exercise 1
# - Create 4 clusters for training and testing, using the same parameters except for the number of samples
# - Plot both training and test in the same plot

# %%
# Training data
X_ex1, y_ex1 = make_blobs(n_samples=100,
                  centers=[(0, 0), (0, 1), (1, 0), (1, 1)],
                  n_features=2,
                  cluster_std=0.2,
                  random_state=999)

# Test data
X_ts_ex1, y_ts_ex1 = make_blobs(n_samples=10,
                  centers=[(0, 0), (0, 1), (1, 0), (1, 1)],
                  n_features=2,
                  cluster_std=0.2,
                  random_state=999)

# %%
X_ex1.shape, X_ts_ex1.shape
# Out:
# ((100, 2), (10, 2))

# %%
# Plot
plt.figure(figsize=(6,6))

# Training set
plt.scatter(X_ex1[:, 0], X_ex1[:, 1], c=y_ex1, cmap='viridis', marker='o', label='Training')

# Test set
plt.scatter(X_ts_ex1[:, 0], X_ts_ex1[:, 1], c=y_ts_ex1, cmap='viridis', marker='x', s=100, label='Test')

plt.title("Training vs Test Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating a deep neural network
#
# Once data is created, we can now develop a model that will discriminate between the three classes of the dataset.
# Pytorch is increadibly flexible, since it already offers all possible operations to create networks.
# We will start by creating a simple network with only dense layers and ReLU activation functions.
#
# ReLU is something that gives non linearity to our model.
# The forward is a method that has to be defined, that embeds the logic of the neural network, exactly how the data flows from the start to the end.
#
# relu(x) = max(0, x)

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(2, 16)  # Input layer to hidden layer
        self.fc2 = torch.nn.Linear(16, 16) # Hidden layer to hidden layer
        self.fc3 = torch.nn.Linear(16, 3)  # Hidden layer to output layer
        self.relu = torch.nn.ReLU()        # ReLU activation function

    def forward(self, x):
        x = self.relu(self.fc1(x))  # Apply first layer and ReLU
        x = self.relu(self.fc2(x))  # Apply second layer and ReLU
        x = self.fc3(x)             # Apply output layer (no activation here)
        return x

model = Net()
print(model)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=3, bias=True)
#   (relu): ReLU()
# )
# Number of parameters: 371

# %% [markdown]
# # Train the network
#
# We can now train our new model on the generated training data.
#
# To do that, we need two ingredients:
#
# * a Loss Function, which quantifies the errors of the model
# * an Optimization Algorithm, to fine-tune the parameters of the model
#
# Hence, through gradient-descent it is possible to iteratively find the optimal parameters for our simple data distribution.
#
# Training is achieved in epochs, which stands for the amount of time the whole dataset is fed to the optimization algorithm to train the weights.
#
# Loss function tells me where to go, the gradient descent moves all the parameters thoward that solution.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

for epoch in range(50):
    model.train()
    running_loss = 0.0
    for inputs, labels in tr_dataloader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward() # Compute gradient (how each weigth contribute to the error)
        optimizer.step() # Update weigth value using calucalte gardient and decreasing lost
        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(tr_dataloader.dataset)
    if (epoch+1) % 10 == 0:
        print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")
# Out:
# Epoch 10, Loss: 0.0420
# Epoch 20, Loss: 0.0378
# Epoch 30, Loss: 0.0370
# Epoch 40, Loss: 0.0364
# Epoch 50, Loss: 0.0359

# %% [markdown]
# We can now test our classifier, by feeding it with test data.

# %%
print(X_test)
# Out:
# tensor([[ 1.0028e+00,  1.0845e+00],
#         [ 1.1092e-01,  1.0199e+00],
#         [ 8.5226e-01,  1.1903e+00],
#         [-3.7682e-02,  1.1626e+00],
#         [-1.5196e-01,  6.9759e-01],
#         [ 1.0047e+00,  1.1481e+00],
#         [ 9.0196e-03,  1.7182e-01],
#         [ 2.4279e-01,  3.0143e-01],
#         [ 4.1158e-01, -1.0118e-01],
#         [ 2.5432e-02,  1.2804e+00],
#         [ 1.2032e-01,  4.4123e-03],
#         [ 1.1186e-01,  1.0948e+00],
#         [ 1.6940e-01,  1.1323e+00],
#         [ 9.2451e-01,  1.2398e+00],
#         [-1.4165e-01,  9.0028e-01],
#         [ 9.2345e-01,  9.5998e-01],
#         [ 5.8608e-01,  1.2088e+00],
#         [-9.7408e-02,  1.1823e+00],
#         [ 1.1798e+00,  9.4949e-01],
#         [ 8.7633e-02,  3.7629e-02],
#         [ 1.2137e+00,  8.9989e-01],
#         [ 2.4407e-01,  7.1619e-02],
#         [ 3.1325e-01,  5.8173e-01],
#         [ 3.4955e-01,  1.4260e+00],
#         [-5.3227e-02,  8.7022e-01],
#         [ 1.0553e+00,  9.9944e-01],
#         [ 1.0453e+00,  8.6154e-01],
#         [-2.3765e-01, -3.3687e-01],
#         [ 6.7286e-01,  1.0562e+00],
#         [-3.1277e-01, -2.4240e-01],
#         [ 8.4966e-02,  1.0013e+00],
#         [ 1.1368e+00,  1.0960e+00],
#         [ 7.4998e-02, -1.4242e-01],
#         [ 1.1670e+00,  8.5483e-01],
#         [-3.2261e-02,  1.3202e+00],
#         [-1.8554e-01, -1.4272e-01],
#         [-3.5421e-03,  3.4037e-01],
#         [ 7.4034e-01,  7.7274e-01],
#         [-8.7671e-02,  2.0639e-01],
#         [ 6.0843e-02,  9.6030e-02],
#         [ 4.1384e-01, -6.0410e-02],
#         [ 4.2500e-02, -4.9409e-02],
#         [ 9.1500e-01,  8.8390e-01],
#         [ 9.6052e-02, -2.1705e-01],
#         [ 9.3856e-01,  1.1048e+00],
#         [ 1.3277e+00,  1.3262e+00],
#         [-3.1296e-01,  1.3666e+00],
#         [ 3.0377e-02,  2.1666e-01],
#         [ 1.2255e-01,  5.1012e-02],
#         [-1.8830e-02,  4.9823e-01],
#         [ 1.0173e+00,  8.9920e-01],
#         [ 2.5690e-01,  9.5956e-01],
#         [ 1.9687e-01,  8.3291e-01],
#         [-8.2388e-02,  1.0866e+00],
#         [ 1.0004e+00,  8.2534e-01],
#         [-7.0518e-02,  9.1822e-01],
#         [ 1.1545e+00,  1.0596e+00],
#         [ 8.8432e-01,  8.4174e-01],
#         [ 7.8846e-01,  8.1463e-01],
#         [-3.7330e-02,  8.2839e-01],
#         [ 1.2684e+00,  8.5352e-01],
#         [ 1.1791e+00,  9.0306e-01],
#         [ 6.2963e-02,  8.2831e-01],
#         [ 1.0422e+00,  7.5908e-01],
#         [-2.1584e-01,  3.8368e-02],
#         [-3.4053e-01,  7.3834e-01],
#         [-4.8195e-04,  1.0138e+00],
#         [-9.4137e-02,  1.0961e+00],
#         [ 4.2711e-01, -4.5995e-02],
#         [-2.8513e-01,  2.8855e-01],
#         [-2.0293e-01,  1.7695e-01],
#         [ 2.7612e-01, -1.0250e-01],
#         [-2.2980e-01,  9.1013e-01],
#         [-2.2029e-01, -8.5541e-02],
#         [-2.6409e-02,  1.1878e+00],
#         [-1.7963e-01,  1.0805e-02],
#         [ 1.2098e-01,  1.0601e+00],
#         [ 2.1324e-01,  1.2313e+00],
#         [-1.1789e-02, -2.9274e-01],
#         [ 1.4231e-02,  6.3167e-01],
#         [ 7.9864e-01,  8.5863e-01],
#         [ 2.6518e-01,  2.1605e-01],
#         [ 7.4384e-01,  1.6141e+00],
#         [-1.5753e-01,  1.1262e+00],
#         [ 1.4601e-02,  1.4699e-01],
#         [-5.0246e-02,  1.1112e+00],
#         [ 9.3826e-01,  8.9634e-01],
#         [ 1.1527e+00,  6.1950e-01],
#         [ 9.0087e-01,  1.1190e+00],
#         [ 2.0172e-01,  4.9427e-02],
#         [ 2.9127e-01,  1.1891e+00],
#         [-9.5552e-02,  3.6326e-01],
#         [ 9.6633e-01,  1.0028e+00],
#         [ 1.3313e-01,  2.1573e-01],
#         [ 3.6633e-01,  1.1766e+00],
#         [ 9.6025e-01,  1.0160e+00],
#         [-2.2201e-01,  8.8304e-01],
#         [-8.0040e-02,  1.0630e+00],
#         [ 2.1786e-02, -7.8254e-03],
#         [ 1.1584e+00,  1.1148e+00]])

# %%
accuracy = (model(X_test).argmax(dim=1) == y_test).float().mean()
print(f"Test Accuracy: {accuracy.item()*100:.2f}%")
# Out:
# Test Accuracy: 100.00%

# %% [markdown]
# Here we don't want just accuracy, but also robustness.
# It can also overfitt the data.

# %%
def plot_decision_regions(model, X, y, title="Decision Regions"):
    """
    Plot decision regions for a PyTorch model.

    Args:
        model: PyTorch model (must be in eval mode)
        X: Input features as tensor
        y: Labels as tensor
        title: Plot title
    """
    # Convert tensors to numpy for plotting
    X_np = X.detach().numpy()
    y_np = y.detach().numpy()

    # Create a mesh grid
    x_min, x_max = X_np[:, 0].min() - 0.5, X_np[:, 0].max() + 0.5
    y_min, y_max = X_np[:, 1].min() - 0.5, X_np[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                         np.linspace(y_min, y_max, 200))

    # Get predictions for each point in the mesh
    X_mesh = torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])
    with torch.no_grad():
        model.eval()
        Z = model(X_mesh)
        Z = torch.argmax(Z, dim=1)
    Z = Z.numpy().reshape(xx.shape)

    # Plot decision regions
    plt.figure(figsize=(10, 8))
    plt.contourf(xx, yy, Z, alpha=0.4, cmap='viridis')

    # Plot data points
    scatter = plt.scatter(X_np[:, 0], X_np[:, 1], c=y_np,
                         cmap='viridis')

    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.title(title)
    plt.show()

# %%
plot_decision_regions(model, X_test, y_test, title="Decision Regions on Test Data")

# %% [markdown]
# ### Exercise 2
#
# Answer these questions:
# 1. What happens if the number of epochs is not enough?
# - under fitting: if the number of epochs is too small.
# - over fitting: if the number of epochs is too big.
#
# 2. What happens if the step-size of the optimizer is too little or too large?
# - missing optiaml solution (learn nothing): if the lr is too small or too big
#
# 3. What happens if the number of parameters of the model are too little?
# - missing complex pattern (under fitting)

# %% [markdown]
# # SecML Torch
#
# We introduce the library we will use during the course, which is [SecML Torch](https://github.com/pralab/secml-torch).
# This Python library, with Pytorch at its core, can import, train and test deep neural network.
#
# We first show how it is possible to train and test the same model with fewer lines of code.

# %%
from secmlt.models.pytorch.base_pytorch_nn import BasePytorchClassifier
from secmlt.models.pytorch.base_pytorch_trainer import BasePyTorchTrainer

net2 = Net()
optimizer = torch.optim.Adam(net2.parameters(), lr=0.01)

trainer = BasePyTorchTrainer(optimizer=optimizer, loss=criterion, epochs=100)
secmlt_model = BasePytorchClassifier(net2, trainer=trainer)
secmlt_model.train(tr_dataloader)
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=3, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# These three lines of code wrap the loop written before.
#
# We can now compute the accuracy on the test.
# To do so, we can create another dataloader for the test data, since all SecML Torch works with dataloaders as input.
# Also, we create an object that takes into account the accuracy score in batches.

# %%
from secmlt.metrics.classification import Accuracy

ts_dataloader = DataLoader(TensorDataset(X_test, y_test), batch_size=32, shuffle=False)

accuracy = Accuracy()(secmlt_model, ts_dataloader)

print("Test accuracy: {:.2f}%".format(accuracy * 100))

plot_decision_regions(secmlt_model.model, X_test, y_test, title="Decision Regions with SecML Torch")
# Out:
# Test accuracy: 100.00%

# %% [markdown]
# ### Exercise 3
#
# * Create a network with 4 dense layers, sigmoid activation function on each layer except for the last.
# * Create the SGD optimizer, the CrossEntropy loss and the SecML Torch objects to wrap the model
# * Train the model, print the accuracy and visualize the decision regions.

# %%
class Net2(torch.nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
        self.fc1 = torch.nn.Linear(2, 32)  # Input layer to hidden layer
        self.fc2 = torch.nn.Linear(32, 64) # Hidden layer to hidden layer
        self.fc3 = torch.nn.Linear(64, 32) # Hidden layer to hidden layer
        self.fc4 = torch.nn.Linear(32, 3)  # Hidden layer to output layer
        self.sigmoid = torch.nn.Sigmoid()  # Sigmoid activation function

    def forward(self, x):
        x = self.sigmoid(self.fc1(x))  # Apply first layer and ReLU
        x = self.sigmoid(self.fc2(x))  # Apply second layer and ReLU
        x = self.sigmoid(self.fc3(x))  # Apply second layer and ReLU
        x = self.fc4(x)                # Apply output layer (no activation here)
        return x

# %%
model = Net2()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
trainer = BasePyTorchTrainer(optimizer=optimizer, loss=criterion, epochs=100)
secmlt_model = BasePytorchClassifier(model, trainer=trainer)
secmlt_model.train(tr_dataloader)
# Out:
# Net2(
#   (fc1): Linear(in_features=2, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=3, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
accuracy = Accuracy()(secmlt_model, ts_dataloader)

print("Test accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Test accuracy: 34.00%

# %%
plot_decision_regions(secmlt_model.model, X_test, y_test, title="Decision Regions with SecML Torch")
